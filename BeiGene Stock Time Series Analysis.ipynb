# %% [markdown]
# ### Introduction:
# I gathered and analyzed stock information for BeiGene, where I interned. BeiGene is a prominent biopharmaceutical company engaging in the discovery, development, and commercialization of innovative cancer treatments. The stock data, encompassing Open-High-Low-Close (OHLC) prices, was diligently sourced from Yahoo Finance.
#
# ### Data Dictionary:
# - **Open:** The price of the stock at the beginning of the trading day.
# - **High:** The highest price of the stock during the trading day.
# - **Low:** The lowest price of the stock during the trading day.
# - **Close:** The price of the stock at the close of the trading day.
#
# ### Objective:
# The primary goal of this analysis is to scrutinize BeiGene's stock performance meticulously through a historical lens, focusing on its OHLC prices. This exploration aims to:
# - Observe and interpret the volatility and trends in BeiGene's stock prices over time.
# - Understand the implications of the stock's historical performance and its inherent market risks.
# - Predict future performance based on historical data, employing various analytical and forecasting techniques.
#
# By achieving these objectives, this analysis endeavors to provide a comprehensive overview of BeiGene’s stock, offering valuable insights for potential investors, market analysts, and financial enthusiasts.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Read the dataset 'BGNE.csv'
df = pd.read_csv('BGNE.csv', index_col='Date', parse_dates=True)
print(df.head())
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2022-06-17  138.270004  141.289993  131.750000  132.139999  132.139999  622300
# 2022-06-21  149.259995  152.979996  139.880005  152.669998  152.669998  836100
# 2022-06-22  148.000000  159.720001  148.000000  155.679993  155.679993  288100
# 2022-06-23  155.679993  159.250000  152.755005  156.199997  156.199997  202800
# 2022-06-24  169.529999  181.830002  166.350006  177.990005  177.990005  534400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2022-06-17 to 2023-06-16
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       251 non-null    float64
#  1   High       251 non-null    float64
#  2   Low        251 non-null    float64
#  3   Close      251 non-null    float64
#  4   Adj Close  251 non-null    float64
#  5   Volume     251 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.7 KB

# %% [markdown]
# This dataframe is now indexed by time values.

# %%
df.index
# Out:
# DatetimeIndex(['2022-06-17', '2022-06-21', '2022-06-22', '2022-06-23',
#                '2022-06-24', '2022-06-27', '2022-06-28', '2022-06-29',
#                '2022-06-30', '2022-07-01',
#                ...
#                '2023-06-05', '2023-06-06', '2023-06-07', '2023-06-08',
#                '2023-06-09', '2023-06-12', '2023-06-13', '2023-06-14',
#                '2023-06-15', '2023-06-16'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
# plot the time series data
df.plot()
plt.show()

# %% [markdown]
# **Graph Readability Issues:**
# - The graph displays only two data types, possibly hiding other four due to range or magnitude differences.
# - Daily data points throughout a year (251 entries) result in cluttered and overlapping points, obscuring values and patterns.
# - The graph lacks context: missing axis labels, titles, or annotations hinder accurate data interpretation.

# %%
# Change the timeframe to half year data
start_date = "2023-01-01"
end_date = "2023-06-30"
half_year_data = df[(df.index >= start_date) & (df.index <= end_date)]

# Plot the filtered data
half_year_data['Close'].plot()
plt.title('First Half-Year Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.show()

# %%
df['Volume'].plot()
plt.show()

# %% [markdown]
# **Stock Trading Volume Overview:**
# - Trading volume represents the number of shares traded daily from open to close.
# - The plot illustrates a volatile trend in daily trading volume, showcasing fluctuations over time with apparent seasonality.
#
# **Observations:**
# - Notably higher trading volumes are observed in Oct, Dec, Apr, and Jul 2023, indicating increased investor activity and engagement during these periods.

# %%
# Resample to a monthly view
df_resampled = df['Close'].resample('M').mean() 

df_resampled.plot()

plt.xlabel('Date')
plt.ylabel('Mean Close Price')
plt.title('Monthly Mean Close Prices')
plt.show()

# %% [markdown]
# Next steps:
# - Decompose the Data: Decompose the time series into three components: trend, seasonality, and noise.
# - Test for Stationarity
# - Choose a model, train the model, and evaluate
